# %%
import os
import xlrd 
import csv
  
# Give the location of the file 
rootdir = 'C:\OTM'
loc = ("customer.xlsx") 

customer = []
ground = []
antenna = []
data = []
equiment_id  = ''
site_id = ''
customer_name = ''
site_name = ''

ground_counter = 0
tower_counter = 0
ce = 'Customer Equipment'
gnd= 'Ground'
twr = 'Tower'
parent ='605034-WT1'
equipment_name ='CE-605034-MTN-7'
eq_header = ["Customer", "SiteNumber", 'Site Name', "Address", 'City', 'Customer Project Name', ]

with open('cust_eq.csv', 'w', newline='') as csvfile:
    cust_eq = csv.writer(csvfile, delimiter=',',escapechar = ' ', quoting=csv.QUOTE_NONE) 
    cust_eq.writerow(eq_header)
    for subdir, dirs, files in os.walk(rootdir):
        for file in files:
            filepath = subdir + os.sep + file
            if filepath.endswith(".xlsx") and not file.startswith('~'):
                print (filepath)		 
                # To open Workbook 
                wb = xlrd.open_workbook(filepath) 
                sheet = wb.sheet_by_index(0) 
#                 print(sheet.cell_value(0, 0))
#                 print(sheet.cell_value(1, 2))
#                 if sheet.cell_value(0, 0) == 'COLLOCATION APPLICATION' and sheet.cell_value(2, 0) == 'SPECIAL PROJECT':
#                     customer_name =  sheet.cell_value(10, 0)  #customer name
#                     customer.append(customer_name)
#                     site_id = sheet.cell_value(10, 2) #site id
#                     customer.append(int(site_id))
#                     customer.append(sheet.cell_value(10,4))  #site name
#                     customer.append(sheet.cell_value(10,6)) #customer site name
#                     customer.append('N/A')
#                     customer.append(sheet.cell_value(10,10)) #lat
#                     customer.append(sheet.cell_value(10,12)) #lon
#                     print(customer)
#                     ground_counter = 0
#                     tower_counter = 0
#                     #get ground equipment
#                     for i in range(22, 27):
#                         if sheet.cell_value(i,0) != "":
#                             ground.append(sheet.cell_value(i,0)) 
#                             print(sheet.cell_value(i,0))
#                             ground.append(sheet.cell_value(i,1)) 
#                             ground.append(sheet.cell_value(i,2)) 
#                             ground.append(sheet.cell_value(i,4)) 
#                             equipment_id = 'CE' + '-' + str(int(site_id)) + '-' + customer_name + '-' +'GND' + str(ground_counter).zfill(2) 
#                             ground.append(equipment_id)
#                             data.append(customer)
#                             data.append(ground)
#                             cust_eq.writerow(data)
#                             ground.clear()
#                             data.clear()
#                             ground_counter += 1

#                         #get tower equipment    
#                     for i in range(32, 40):
#                         if sheet.cell_value(i,0) != "":
#                             print(antenna.append(sheet.cell_value(i,3)))
#                             qty = int(sheet.cell_value(i,3))
#                             for y in range(1): # equipment count
#                                 antenna.append(sheet.cell_value(i,1)) #instalation status
#                                 antenna.append(sheet.cell_value(i,4)) #equipment type
#                                 antenna.append(sheet.cell_value(i,4)) #mount type
#                                 antenna.append(sheet.cell_value(i,2))  #antena height
#                                 antenna.append(sheet.cell_value(i,7))   #antenna make   
#                                 antenna.append(sheet.cell_value(i,8))   #antenna model  
#                                 antenna.append(sheet.cell_value(i,9))   #antenna height             
#                                 antenna.append(sheet.cell_value(i,10))   #antenna width  
#                                 antenna.append(sheet.cell_value(i,11))   #antenna depth 
#                                 antenna.append(sheet.cell_value(i,13))  #antena azimuth
#                                 antenna.append(sheet.cell_value(i,14))  #antena feeder qty           
#                                 equipment_id = 'CE' + '-' + str(int(site_id)) + '-' + customer_name + '-' +'WT' + str(tower_counter).zfill(2) 
#                                 antenna.append(equipment_id)
#                                 data.append(customer)
#                                 data.append(antenna)
#                                 cust_eq.writerow(data)
#                                 antenna.clear()
#                                 data.clear()
#                                 tower_counter += 1

                if sheet.cell_value(0, 0) == 'COLLOCATION APPLICATION' and sheet.cell_value(2, 2) != 'Fibre Application' and sheet.cell_value(2, 0) == 'ATC SALES REPRESENTATIVE':
                    print('mod file')
                   # for x in range(sheet.cell_value(79, i)): # number of antennas, must be record for eatch one
                    customer_name =  sheet.cell_value(6, 2)  #customer name
                    customer.append(customer_name)
                    site_id = sheet.cell_value(8, 2)  #site id
                    customer.append(int(site_id))
                    site_name = sheet.cell_value(8,9)  # customer site name
                    customer.append(site_name)
                    customer.append(sheet.cell_value(15,2)) #address
                    customer.append(sheet.cell_value(10,1)) #lat
                    customer.append(sheet.cell_value(10,4)) #lon
                    ground_counter = 0
                    tower_counter = 0
                    for i in range(3, 12,2):
                        if sheet.cell_value(78,(3 + i)) != "":
                            for x in range(sheet.cell_value(79, i)): # number of antennas, must be record for eatch one
                                antenna.append(sheet.cell_value(78,i)) # Antenna Type
                                antenna.append(1)# qty anttenna set to 1
                                antenna.append(sheet.cell_value(80,i)) #manufaturer
                                antenna.append(sheet.cell_value(81,i)) #antenna Model
                                antenna.append(sheet.cell_value(82,i)) #antenna type
                                antenna.append(sheet.cell_value(105,i)) #line type
                                #asimuth must be added
                                data.append(customer)
                                data.append(antenna)
                                equipment_id = 'CE' + '-' + str(int(site_id)) + '-' + customer_name + '-' +'WT' + str(tower_counter).zfill(2) 
                                print(equipment_id)
                                cust_eq.writerow(data)
                                antenna.clear()
                                data.clear()
                                tower_counter += 1
                customer.clear()
# Out:
# C:\OTM\350007 - Log Square\24420 = Cell C - Fiber - S -\350007_CAP_080116.xlsx
# C:\OTM\350007 - Log Square\38198 = Telkom (Full Install)\350007_CAP_261118.xlsx
# C:\OTM\350007 - Log Square\38198 = Telkom (Full Install)\350007_NTP_260719.xlsx
# C:\OTM\350007 - Log Square\38198 = Telkom (Full Install)\350007_PRE APPROVAL_281118.xlsx
# C:\OTM\350007 - Log Square\38198 = Telkom (Full Install)\GC Log Square - AAU Application.xlsx
# C:\OTM\350007 - Log Square\40340 = RAIN (Full Install)\350007_CAP_130619.xlsx
# C:\OTM\350007 - Log Square\40340 = RAIN (Full Install)\350007_Pre.App_130619.xlsx
# C:\OTM\350008 - Droste Park\29951 = Cell C (Fibre)\NTP_ 350008_ Doste Park_ Cell C - 1010_ Fibre (Self - Build)_ WF 29951.xlsx
# C:\OTM\350008 - Droste Park\36325 = Telkom (Full Installation)\350008_CAP_260718.xlsx
# C:\OTM\350008 - Droste Park\36325 = Telkom (Full Installation)\350008_Droste Psark_GC 6273_Pre.Approval_300718.xlsx
# ...

# %%
import csv

poles_file = 'SA_Poles_Customer_Equipment.csv'
towers_file ='SA_Towers_Customer_Equipment.csv'

with open(poles_file, newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

for i in data: 
    if (i[0][0:2] == '35') and (i[0][2:3] != 'm'):
        if i[0] == '350017':
            print(i)
            
            
with open(towers_file, newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

for i in data: 
    if (i[0][0:2] == '35') and (i[0][2:3] != 'm'):
        if i[0] == '350017-1':
            print(i)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-9af739caf2c2> in <module>
#       4 towers_file ='SA_Towers_Customer_Equipment.csv'
#       5
# ----> 6 with open(poles_file, newline='') as f:
#       7     reader = csv.reader(f)
#       8     data = list(reader)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SA_Poles_Customer_Equipment.csv'
